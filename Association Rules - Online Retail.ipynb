# %% [markdown]
# ### Import Libraries

# %%
#!pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\836916.india\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: setuptools in c:\users\836916.india\anaconda3\lib\site-packages (from mlxtend) (58.0.4)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\836916.india\anaconda3\lib\site-packages (from mlxtend) (3.4.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\836916.india\anaconda3\lib\site-packages (from mlxtend) (1.3.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\836916.india\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\836916.india\anaconda3\lib\site-packages (from mlxtend) (1.20.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\836916.india\anaconda3\lib\site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\836916.india\anaconda3\lib\site-packages (from mlxtend) (1.7.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\836916.india\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\836916.india\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\836916.india\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\836916.india\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\836916.india\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (8.4.0)
# Requirement already satisfied: six in c:\users\836916.india\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\836916.india\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\836916.india\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Data

# %%
online_retail=pd.read_excel('..\\may 5 batch codes\\Data Files\\Online Retail.xlsx')
online_retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Data Understanding

# %%
online_retail.shape
# Out:
# (541909, 8)

# %%
online_retail.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
online_retail.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %% [markdown]
# ### Data Preparation

# %%
online_retail.drop('CustomerID',axis=1,inplace=True)

# %%
online_retail.dropna(inplace=True)

# %%
online_retail.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# Country        0
# dtype: int64

# %%
france_data=online_retail[online_retail['Country']=='France']
france_data.head()
# Out:
#    InvoiceNo StockCode                      Description  Quantity  \
# 26    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30    536370     21883                 STARS GIFT TAPE         24
#
#            InvoiceDate  UnitPrice Country
# 26 2010-12-01 08:45:00       3.75  France
# 27 2010-12-01 08:45:00       3.75  France
# 28 2010-12-01 08:45:00       3.75  France
# 29 2010-12-01 08:45:00       0.85  France
# 30 2010-12-01 08:45:00       0.65  France

# %%
france_data_pivot=pd.pivot_table(data=france_data,values='Quantity',index='InvoiceNo',columns='Description').fillna(0)
france_data_pivot.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                  0.0                 0.0
# 536852                                  0.0                 0.0
# 536974                                  0.0                 0.0
# 537065                                  0.0                 0.0
# 537463                                  0.0                 0.0
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                                0.0                       0.0
# 536852                                0.0                       0.0
# 536974                                0.0                       0.0
# 537065                                0.0                       0.0
# 537463                                0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536370                                   24.0                      0.0
# 536852                                    0.0                      0.0
# 536974                                    0.0                      0.0
# 537065                                    0.0                      0.0
# 537463                                    0.0                      0.0
#
# Description   TRELLIS COAT RACK  10 COLOUR SPACEBOY PEN  \
# InvoiceNo
# 536370                      0.0                     0.0
# 536852                      0.0                     0.0
# 536974                      0.0                     0.0
# 537065                      0.0                     0.0
# 537463                      0.0                     0.0
#
# Description  12 COLOURED PARTY BALLOONS  12 EGG HOUSE PAINTED WOOD  ...  \
# InvoiceNo                                                           ...
# 536370                              0.0                        0.0  ...
# 536852                              0.0                        0.0  ...
# 536974                              0.0                        0.0  ...
# 537065                              0.0                        0.0  ...
# 537463                              0.0                        0.0  ...
#
# Description  WRAP VINTAGE PETALS  DESIGN  YELLOW COAT RACK PARIS FASHION  \
# InvoiceNo
# 536370                               0.0                             0.0
# 536852                               0.0                             0.0
# 536974                               0.0                             0.0
# 537065                               0.0                             0.0
# 537463                               0.0                             0.0
#
# Description  YELLOW GIANT GARDEN THERMOMETER  YELLOW SHARK HELICOPTER  \
# InvoiceNo
# 536370                                   0.0                      0.0
# 536852                                   0.0                      0.0
# 536974                                   0.0                      0.0
# 537065                                   0.0                      0.0
# 537463                                   0.0                      0.0
#
# Description  ZINC  STAR T-LIGHT HOLDER   ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536370                              0.0                        0.0
# 536852                              0.0                        0.0
# 536974                              0.0                        0.0
# 537065                              0.0                        0.0
# 537463                              0.0                        0.0
#
# Description  ZINC HERB GARDEN CONTAINER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536370                              0.0                          0.0
# 536852                              0.0                          0.0
# 536974                              0.0                          0.0
# 537065                              0.0                          0.0
# 537463                              0.0                          0.0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
#
# [5 rows x 1565 columns]

# %%
france_data_encoded=france_data_pivot.applymap(lambda x: 1 if x>0 else 0)
france_data_encoded.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                    0                   0
# 536852                                    0                   0
# 536974                                    0                   0
# 537065                                    0                   0
# 537463                                    0                   0
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                                  0                         0
# 536852                                  0                         0
# 536974                                  0                         0
# 537065                                  0                         0
# 537463                                  0                         0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536370                                      1                        0
# 536852                                      0                        0
# 536974                                      0                        0
# 537065                                      0                        0
# 537463                                      0                        0
#
# Description   TRELLIS COAT RACK  10 COLOUR SPACEBOY PEN  \
# InvoiceNo
# 536370                        0                       0
# 536852                        0                       0
# 536974                        0                       0
# 537065                        0                       0
# 537463                        0                       0
#
# Description  12 COLOURED PARTY BALLOONS  12 EGG HOUSE PAINTED WOOD  ...  \
# InvoiceNo                                                           ...
# 536370                                0                          0  ...
# 536852                                0                          0  ...
# 536974                                0                          0  ...
# 537065                                0                          0  ...
# 537463                                0                          0  ...
#
# Description  WRAP VINTAGE PETALS  DESIGN  YELLOW COAT RACK PARIS FASHION  \
# InvoiceNo
# 536370                                 0                               0
# 536852                                 0                               0
# 536974                                 0                               0
# 537065                                 0                               0
# 537463                                 0                               0
#
# Description  YELLOW GIANT GARDEN THERMOMETER  YELLOW SHARK HELICOPTER  \
# InvoiceNo
# 536370                                     0                        0
# 536852                                     0                        0
# 536974                                     0                        0
# 537065                                     0                        0
# 537463                                     0                        0
#
# Description  ZINC  STAR T-LIGHT HOLDER   ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536370                                0                          0
# 536852                                0                          0
# 536974                                0                          0
# 537065                                0                          0
# 537463                                0                          0
#
# Description  ZINC HERB GARDEN CONTAINER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536370                                0                            0
# 536852                                0                            0
# 536974                                0                            0
# 537065                                0                            0
# 537463                                0                            0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                    0                                0
# 536852                                    0                                0
# 536974                                    0                                0
# 537065                                    0                                0
# 537463                                    0                                0
#
# [5 rows x 1565 columns]

# %% [markdown]
# ### Model Building // Data Mining

# %%
frequent_itemsets=apriori(df=france_data_encoded,min_support=0.03,use_colnames=True)
frequent_itemsets
# Out:
#       support                                           itemsets
# 0    0.034707                          ( SPACEBOY BABY GIFT SET)
# 1    0.030369               (3 PIECE SPACEBOY COOKIE CUTTER SET)
# 2    0.039046                    (36 PENCILS TUBE RED RETROSPOT)
# 3    0.060738                      (4 TRADITIONAL SPINNING TOPS)
# 4    0.082430                       (ALARM CLOCK BAKELIKE GREEN)
# ..        ...                                                ...
# 479  0.030369  (SET/6 RED SPOTTY PAPER CUPS, PACK OF 6 SKULL ...
# 480  0.030369  (SET/6 RED SPOTTY PAPER CUPS, PACK OF 6 SKULL ...
# 481  0.032538  (SET/6 RED SPOTTY PAPER PLATES, PACK OF 6 SKUL...
# 482  0.045553  (PLASTERS IN TIN CIRCUS PARADE , PLASTERS IN T...
# 483  0.069414  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
#
# [484 rows x 2 columns]

# %%
best_associates=association_rules(df=frequent_itemsets,metric='confidence',min_threshold=0.8)
best_associates
# Out:
#                                            antecedents  \
# 0                          (ALARM CLOCK BAKELIKE RED )
# 1                         (ALARM CLOCK BAKELIKE GREEN)
# 2                         (ALARM CLOCK BAKELIKE GREEN)
# 3                        (ALARM CLOCK BAKELIKE ORANGE)
# 4                        (ALARM CLOCK BAKELIKE ORANGE)
# ..                                                 ...
# 274  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 275  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 276  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 277  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 278  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
#
#                                   consequents  antecedent support  \
# 0                (ALARM CLOCK BAKELIKE GREEN)            0.080260
# 1                 (ALARM CLOCK BAKELIKE RED )            0.082430
# 2                                   (POSTAGE)            0.082430
# 3                 (ALARM CLOCK BAKELIKE RED )            0.036876
# 4                                   (POSTAGE)            0.036876
# ..                                        ...                 ...
# 274     (SET/20 RED RETROSPOT PAPER NAPKINS )            0.086768
# 275             (SET/6 RED SPOTTY PAPER CUPS)            0.071584
# 276           (SET/6 RED SPOTTY PAPER PLATES)            0.071584
# 277    (SET/6 RED SPOTTY PAPER CUPS, POSTAGE)            0.086768
# 278  (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)            0.086768
#
#      consequent support   support  confidence       lift  leverage  conviction
# 0              0.082430  0.067245    0.837838  10.164296  0.060629    5.658351
# 1              0.080260  0.067245    0.815789  10.164296  0.060629    4.992873
# 2              0.650759  0.071584    0.868421   1.334474  0.017942    2.654230
# 3              0.080260  0.030369    0.823529  10.260731  0.027409    5.211858
# 4              0.650759  0.032538    0.882353   1.355882  0.008540    2.968547
# ..                  ...       ...         ...        ...       ...         ...
# 274            0.112798  0.069414    0.800000   7.092308  0.059627    4.436009
# 275            0.117137  0.069414    0.969697   8.278339  0.061029   29.134490
# 276            0.108460  0.069414    0.969697   8.940606  0.061650   29.420824
# 277            0.099783  0.069414    0.800000   8.017391  0.060756    4.501085
# 278            0.091106  0.069414    0.800000   8.780952  0.061509    4.544469
#
# [279 rows x 9 columns]

# %% [markdown]
# ### Here, we got the Best associates by removing redundant rules.

# %%
best_associates.to_csv('best_associates.csv')

# %% [markdown]
# ### End
